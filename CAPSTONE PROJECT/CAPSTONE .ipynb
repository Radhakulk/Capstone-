# %% [markdown]
# # _____________     Capstone Project   phase -1   __________________

# %% [markdown]
# # Description
# Data Collection/preparation part.

# %% [markdown]
# Note:
#
# You can collect data from anywhere (wiki, google, etc) but mention the link from where data is being collected.
#
# You can collect the data manually. It's NOT a web scraping task.
#
# Data should be collected for the years mentioned in the files. (If you don't find proper data, make your best judgment and fill it, It's absolutely OK. Do not worry about data accuracy.)
#
#
# Data
#
# * The population of each state.
# * Literacy Rate in each state
# * Area of each state
# * Collect any other data that helps with your analysis. There is no limitation for anything.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Link of website from where i have collected data :
# * Area of states : https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area
# ![image.png](attachment:image.png)
# * 2001 population : http://demographia.com/db-india-ur2001.htm
# ![image-2.png](attachment:image-2.png)
# * 2001 male & female population :http://cyberjournalist.org.in/census/cenindia.html
# ![image-3.png](attachment:image-3.png)
# * 2011 population :https://statistics.py.gov.in/state-wise-population
# ![image-4.png](attachment:image-4.png)
#
# * Litaracy rate :https://mospi.gov.in/sites/default/files/reports_and_publication/statistical_publication/social_statistics/WM16Chapter3.pdf
# ![image-5.png](attachment:image-5.png)
#
# * Crime rate :https://ncrb.gov.in/crime-in-india-table-content.html?year=2019&category=Summary+%28States%2FUTs%29
# ![image-6.png](attachment:image-6.png)

# %%
link=pd.read_excel(r'C:\Users\Administrator\Documents\Capstone data.xlsx')
link
# Out:
#   https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area  \
# 0         http://demographia.com/db-india-ur2001.htm
# 1  http://cyberjournalist.org.in/census/cenindia....
# 2  https://statistics.py.gov.in/state-wise-popula...
# 3  https://mospi.gov.in/sites/default/files/repor...
# 4  https://ncrb.gov.in/crime-in-india-table-conte...
#
#                      Area Link
# 0              2001 population
# 1  2001 male&female population
# 2              2011 population
# 3                literacy rate
# 4                   Crime rate

# %% [markdown]
# Theese are the links from where i have collected the data.

# %%
path=r'C:\Users\Administrator\Documents\Capstone data.xlsx'
df=pd.read_excel(path,sheet_name='Data')
df
# Out:
#                         State  Area (km2)  2001 Population         Unnamed: 3  \
# 0                         NaN         NaN  Male population  Female population
# 1   Andaman & Nicobar Islands      8249.0           192985             163280
# 2              Andhra Pradesh    162975.0         38286811           37440730
# 3           Arunachal Pradesh     83743.0           573951             517166
# 4                       Assam     78438.0         13787799           12850608
# 5                       Bihar     94163.0         43153964           39724832
# 6                  Chandigarh       114.0           508224             392690
# 7                 Chhatisgarh    135192.0         10452426           10343530
# 8        Dadra & Nagar Haveli       603.0           121731              98720
# 9                 Daman & Diu      3702.0            92478              65581
# 10                      Delhi      1484.0          7570890            6212086
# ...

# %%
#checking for shape
df.shape
# Out:
# (36, 17)

# %%
#checking for columns
df.columns.to_list()
# Out:
# ['State',
#  'Area (km2)',
#  '2001 Population',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  '2011 population',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Literacy Rates in 2001',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Literacy Rates in 2011',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Total IPC & SLL Crimes (State/UT-wise) - 2017-2019',
#  'Unnamed: 15',
#  'Unnamed: 16']

# %%
These are the columns name of the data.
